# %%
#In this project I will visualize a dataset of the Euro exchange rate from 1999 to 2023

# %%
#importing the libraries and the data I am going to use
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


pd.set_option('display.max_rows', None)
exchange_rates = pd.read_csv(r"D:\exel\Protfolio Project\Python project\Euro exchange rates data visialisation project\euro-daily-hist_1999_2022.csv")

# %%
exchange_rates.head(5)
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0    1/27/2023               1.5289           1.9558            5.5104
# 1    1/26/2023               1.5308           1.9558            5.5572
# 2    1/25/2023                1.536           1.9558             5.569
# 3    1/24/2023                1.547           1.9558            5.6164
# 4    1/23/2023               1.5529           1.9558            5.6372
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4479         1.0017                    7.369              NaN
# 1             1.4568         1.0002                   7.3893              NaN
# 2             1.4544          1.002                   7.3778              NaN
# 3             1.4517         1.0053                   7.3642              NaN
# 4             1.4523         1.0013                    7.373              NaN
#
# ...

# %%
exchange_rates.tail(5)
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6224     1/8/1999               1.8406              NaN               NaN
# 6225     1/7/1999               1.8474              NaN               NaN
# 6226     1/6/1999                1.882              NaN               NaN
# 6227     1/5/1999               1.8944              NaN               NaN
# 6228     1/4/1999                 1.91              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6224             1.7643         1.6138                      NaN
# 6225             1.7602         1.6165                      NaN
# 6226             1.7711         1.6116                      NaN
# 6227             1.7965         1.6123                      NaN
# 6228             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6229 entries, 0 to 6228
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6229 non-null   object
#  1   [Australian dollar ]      6229 non-null   object
#  2   [Bulgarian lev ]          5827 non-null   object
#  3   [Brazilian real ]         5961 non-null   object
#  4   [Canadian dollar ]        6229 non-null   object
#  5   [Swiss franc ]            6229 non-null   object
#  6   [Chinese yuan renminbi ]  5961 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6229 non-null   object
#  9   [Danish krone ]           6229 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6229 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
#rename columns and changing Dtype for the ['Time'] column

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)

# %%
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
#Showing corraletion between diffrent currencies In with regard to the Euro

# %%
exchange_rates_corr = exchange_rates.iloc[: , 1: ]

# %%
for col in exchange_rates_corr.columns:
    exchange_rates_corr.loc[exchange_rates_corr[col] == '-', col] = None
    exchange_rates_corr[col] = exchange_rates_corr[col].astype(float)

# %%
exchange_rates_corr.corr(method ='pearson')
# Out:
#                           [Australian dollar ]  [Bulgarian lev ]  \
# [Australian dollar ]                  1.000000         -0.359705
# [Bulgarian lev ]                     -0.359705          1.000000
# [Brazilian real ]                     0.090509          0.253376
# [Canadian dollar ]                    0.689778         -0.039235
# [Swiss franc ]                        0.521402         -0.375288
# [Chinese yuan renminbi ]              0.300396          0.092602
# [Cypriot pound ]                      0.107656          0.017291
# [Czech koruna ]                       0.433305         -0.728800
# [Danish krone ]                      -0.099014          0.288221
# [Estonian kroon ]                          NaN               NaN
# [UK pound sterling ]                 -0.365917          0.594812
# [Greek drachma ]                     -0.457720          0.562888
# [Hong Kong dollar ]                  -0.199597          0.539002
# ...

# %%
plt.figure(figsize = (14, 12))
correlation_matrix = exchange_rates_corr.iloc[ : ,11 :  22].corr(method ='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for different currencies Euro exchange rate", weight='bold')

plt.xlabel("currency name")

plt.ylabel("currency name")

plt.show()

# %%
# As we can see there is a high correlation between the Indonesian rupiah snd the Indian rupee euro exchange rate

# %%
# Creating a table for only the Euro to US dollar Exchange rate and changing us dollar Dtype to float

# %%
euro_to_dollar = exchange_rates.iloc[ : , [0, 39]]

# %%
euro_to_dollar.head(5)
# Out:
#            Time US_dollar
# 0    1999-01-04    1.1789
# 1    1999-01-05     1.179
# 2    1999-01-06    1.1743
# 3    1999-01-07    1.1632
# 4    1999-01-08    1.1659
# 5    1999-01-11    1.1569
# 6    1999-01-12     1.152
# 7    1999-01-13    1.1744
# 8    1999-01-14    1.1653
# 9    1999-01-15    1.1626
# 10   1999-01-18    1.1612
# 11   1999-01-19    1.1616
# 12   1999-01-20    1.1575
# 13   1999-01-21    1.1572
# 14   1999-01-22    1.1567
# 15   1999-01-25    1.1584
# 16   1999-01-26    1.1582
# 17   1999-01-27    1.1529
# 18   1999-01-28     1.141
# 19   1999-01-29    1.1384
# 20   1999-02-01    1.1338
# 21   1999-02-02    1.1337
# 22   1999-02-03    1.1337
# 23   1999-02-04    1.1263
# 24   1999-02-05    1.1292
# 25   1999-02-08    1.1246
# 26   1999-02-09    1.1333
# 27   1999-02-10    1.1342
# 28   1999-02-11    1.1312
# 29   1999-02-12    1.1244
# 30   1999-02-15    1.1238
# 31   1999-02-16    1.1176
# 32   1999-02-17    1.1253
# 33   1999-02-18    1.1232
# ...

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1268     7
# 1.1305     7
# 1.3532     6
# 1.1579     6
# 1.1345     6
# 1.1279     6
# 1.1193     6
# 1.1797     6
# 1.1765     6
# 1.3086     6
# 1.1218     6
# 1.2713     6
# 1.1346     6
# 1.0867     6
# 1.2143     6
# 1.3373     6
# 1.1354     6
# 1.0888     6
# 1.1185     5
# 1.2737     5
# 1.0572     5
# 1.32       5
# 1.326      5
# 1.1156     5
# 1.2219     5
# 1.3596     5
# 1.2309     5
# 1.3246     5
# 1.1154     5
# 1.0772     5
# 1.3588     5
# 1.1348     5
# 1.1146     5
# 1.1336     5
# 1.1403     5
# 1.1236     5
# 1.3574     5
# 1.1933     5
# 1.3615     5
# 1.3035     5
# 1.1025     5
# 1.1342     5
# 1.1328     5
# 1.1187     5
# 1.0737     5
# 1.1115     5
# 1.1787     5
# 1.1221     5
# 1.1389     5
# 1.1168     5
# 0.8803     5
# 1.1569     5
# 1.285      5
# 1.1312     5
# 1.1138     5
# 1.137      5
# 1.1318     5
# 1.1813     5
# 1.1284     5
# 1.0592     5
# 1.3192     4
# 1.086      4
# 1.304      4
# ...

# %%
euro_to_dollar = euro_to_dollar.loc[ euro_to_dollar['US_dollar'] != '-']
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

# %%
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6167 entries, 0 to 6228
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       6167 non-null   datetime64[ns]
#  1   US_dollar  6167 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 144.5 KB

# %%
# showing the Euro to US dollar exchange rate over the time

# %%
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %%
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'].rolling(30).mean())
plt.title('Euro to dollar exchange rate over the time with a rolling window of a month', weight='bold')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(9,6))

plt.subplot(3,2,1)
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.title('Original values', weight='bold')

for i, rolling_mean in zip([2, 3, 4, 5, 6],
                           [7, 30, 50, 100, 365]):
    plt.subplot(3,2,i)
    plt.plot(euro_to_dollar['Time'],
             euro_to_dollar['US_dollar'].rolling(rolling_mean).mean())
    plt.title('Rolling Window:' + str(rolling_mean), weight='bold')
    
plt.tight_layout()
plt.show()

# %%
# Euro to dollar exchange rate during Bush, Obama and Trump presidensy

# %%
euro_to_dollar_Bush = euro_to_dollar.loc[(euro_to_dollar['Time'] > '1999-12-31') &
                                         (euro_to_dollar['Time'] <= '2008-12-31')]


euro_to_dollar_Obama = euro_to_dollar.loc[(euro_to_dollar['Time'] > '2008-12-31') &
                                         (euro_to_dollar['Time'] <= '2016-12-31')]


euro_to_dollar_Trump = euro_to_dollar.loc[(euro_to_dollar['Time'] > '2016-12-31') &
                                         (euro_to_dollar['Time'] <= '2020-12-31')]

# %%
plt.style.use('ggplot')
plt.figure(figsize=(11,7))

plt.subplot(3,2,1)
plt.plot(euro_to_dollar_Bush['Time'], euro_to_dollar_Bush['US_dollar'].rolling(30).mean())
plt.title('Bush', weight='bold')
plt.ylabel('Euro to US dollar')

plt.subplot(3,2,2)
plt.plot(euro_to_dollar_Obama['Time'], euro_to_dollar_Obama['US_dollar'].rolling(30).mean())
plt.title('Obama ', weight='bold')
plt.ylabel('Euro to US dollar')

plt.subplot(3,2,3)
plt.plot(euro_to_dollar_Trump['Time'], euro_to_dollar_Trump['US_dollar'].rolling(30).mean())
plt.title('Trump ', weight='bold')
plt.ylabel('Euro to US dollar')

    
plt.tight_layout()
plt.show()

# %%
### Ax4: Bush-Obama-Trump\
plt.figure(figsize=(25,10))
plt.plot(euro_to_dollar_Bush['Time'], euro_to_dollar_Bush['US_dollar'].rolling(30).mean(),
        color='purple', linewidth=9)
plt.plot(euro_to_dollar_Obama['Time'], euro_to_dollar_Obama['US_dollar'].rolling(30).mean(),
        color='orange', linewidth=9)
plt.plot(euro_to_dollar_Trump['Time'], euro_to_dollar_Trump['US_dollar'].rolling(30).mean(),
        color='white', linewidth=9)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(['Bush', 'Obama', 'Trump'], fontsize="30");

# %%
# The euro to US dollar exchange rate was at its lowest point during the end of Obama's era and the begining of Trump's
